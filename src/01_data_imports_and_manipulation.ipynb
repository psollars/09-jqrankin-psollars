# %% [markdown]
# # Importing the Raw Datasets

# %%
import pandas as pd

wdi_df = pd.read_csv("./data/WDIData.csv")

# Output the first 100 records as a sample set
wdi_df.head(100).to_csv("./data/WDIData_sample.csv")

wdi_df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.936004  17.337896  17.687093
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.499471   6.680066   6.859110
# 2   NaN   NaN   NaN   NaN   NaN  ...  37.855399  38.046781  38.326255
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.794160  32.001027  33.871910
# 4   NaN   NaN   NaN   NaN   NaN  ...  18.663502  17.633986  16.464681
#
#         2016       2017       2018       2019       2020  2021  Unnamed: 66
# 0  18.140971  18.491344  18.825520  19.272212  19.628009   NaN          NaN
# 1   7.016238   7.180364   7.322294   7.517191   7.651598   NaN          NaN
# 2  38.468426  38.670044  38.722783  38.927016  39.042839   NaN          NaN
# 3  38.880173  40.261358  43.061877  44.270860  45.803485   NaN          NaN
# 4  24.531436  25.345111  27.449908  29.641760  30.404935   NaN          NaN
#
# [5 rows x 67 columns]

# %%
climate_df = pd.read_csv("./data/climate_watch_data.csv")

climate_df.head()
# Out:
#   Country Data source                Sector      Gas    Unit      2019  \
# 0   World        CAIT  Total including LUCF  All GHG  MtCO₂e  49758.23
# 1   World        CAIT  Total excluding LUCF  All GHG  MtCO₂e  48116.56
# 2   World        CAIT                Energy  All GHG  MtCO₂e  37636.10
# 3   World        CAIT  Total including LUCF      CO2  MtCO₂e  36874.11
# 4   World        CAIT  Total excluding LUCF      CO2  MtCO₂e  35512.86
#
#        2018      2017      2016      2015  ...      1999      1998      1997  \
# 0  49368.04  48251.88  47531.68  46871.77  ...  35101.90  35099.21  35537.18
# 1  47980.47  47031.82  46264.07  46085.31  ...  33282.05  33088.07  32855.85
# 2  37603.22  36777.63  36188.89  36173.70  ...  25389.87  25257.77  25075.28
# 3  36669.40  35736.22  35223.63  34559.71  ...  25064.85  25003.46  25396.41
# 4  35476.59  34689.96  34144.04  34076.29  ...  23506.53  23348.62  23185.61
#
#        1996      1995      1994      1993      1992      1991      1990
# 0  34179.33  33805.61  33015.04  32729.06  32588.09  32670.51  32523.58
# 1  32467.96  31890.42  31105.68  30819.73  30678.77  30761.18  30614.25
# 2  24656.11  24150.88  23501.77  23395.58  23265.41  23365.41  23244.24
# 3  24289.64  23964.26  23334.16  23191.71  23049.37  23098.30  22943.37
# 4  22769.14  22289.91  21665.65  21523.23  21380.89  21429.81  21274.89
#
# [5 rows x 35 columns]

# %%
un_sds_df = pd.read_excel("./data/un_sds_poverty_data.xlsx")

un_sds_df.head()
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     1    1.1     1.1.1  SI_POV_DAY1
# 1     1    1.1     1.1.1  SI_POV_DAY1
# 2     1    1.1     1.1.1  SI_POV_DAY1
# 3     1    1.1     1.1.1  SI_POV_DAY1
# 4     1    1.1     1.1.1  SI_POV_DAY1
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Proportion of population below international p...            1       World
# 1  Proportion of population below international p...            1       World
# 2  Proportion of population below international p...            1       World
# 3  Proportion of population below international p...            1       World
# 4  Proportion of population below international p...            1       World
#
#    TimePeriod  Value Time_Detail  ...                FootNote     Age  \
# 0        1981   42.6        1981  ...  Accessed April 8, 2022  ALLAGE
# 1        1982   42.1        1982  ...  Accessed April 8, 2022  ALLAGE
# 2        1983   41.3        1983  ...  Accessed April 8, 2022  ALLAGE
# 3        1984   39.6        1984  ...  Accessed April 8, 2022  ALLAGE
# 4        1985   38.0        1985  ...  Accessed April 8, 2022  ALLAGE
#
#    Hazard type  Location Nature  Observation Status Quantile Reporting Type  \
# 0          NaN   ALLAREA      G                 NaN      NaN              G
# 1          NaN   ALLAREA      G                 NaN      NaN              G
# 2          NaN   ALLAREA      G                 NaN      NaN              G
# 3          NaN   ALLAREA      G                 NaN      NaN              G
# 4          NaN   ALLAREA      G                 NaN      NaN              G
#
#        Sex    Units
# 0  BOTHSEX  PERCENT
# 1  BOTHSEX  PERCENT
# 2  BOTHSEX  PERCENT
# 3  BOTHSEX  PERCENT
# 4  BOTHSEX  PERCENT
#
# [5 rows x 26 columns]

# %% [markdown]
# # Matching Country Names
#
# Some countries do not share a common name between the datasets. The following code was used to generate lists of unique country names not included in the other datasets.
#
# Since the GHG data contained the smallest number of country names it was chosen as the “source of truth” for country labels.

# %%
climate_countries = climate_df["Country"].unique()
wdi_countries = wdi_df["Country Name"].unique()
un_sds_countries = sorted(un_sds_df["GeoAreaName"].unique())

in_climate_not_wdi = list(set(climate_countries).difference(set(wdi_countries)))
in_climate_not_un = list(set(climate_countries).difference(set(un_sds_countries)))

# %% [markdown]
# Mapping GHG Country names to other datasets was not a process that led itself to automation. In the case of countries like `Kyrgyz Republic/Kyrgyzstan` it might've been possible, but difficult to use partial matching to connect the names together. With a total list of 34 country names, this was a task that we undertook manually with discretion.

# %% [markdown]
# | Greenhouse Gas Emissions         | World Development Indicators (GDP Data) | Global Poverty Data                                      |
# | -------------------------------- | --------------------------------------- | -------------------------------------------------------- |
# | Bahamas                          | **Bahamas, The**                        | Bahamas                                                  |
# | Bolivia                          | Bolivia                                 | **Bolivia (Plurinational State of)**                     |
# | Brunei                           | **Brunei Darussalam**                   | **Brunei Darussalam**                                    |
# | Cape Verde                       | **Cabo Verde**                          | **Cabo Verde**                                           |
# | Cook Islands                     | _N/A_                                   | Cook Islands                                             |
# | Côte d'Ivoire                    | **Cote d'Ivoire**                       | Côte d'Ivoire                                            |
# | Czech Republic                   | Czech Republic                          | **Czechia**                                              |
# | Democratic Republic of the Congo | **Congo, Dem. Rep.**                    | Democratic Republic of the Congo                         |
# | Egypt                            | **Egypt, Arab Rep.**                    | Egypt                                                    |
# | European Union (27)              | **European Union**                      | _N/A_                                                    |
# | Gambia                           | **Gambia, The**                         | Gambia                                                   |
# | Iran                             | **Iran, Islamic Rep.**                  | **Iran (Islamic Republic of)**                           |
# | Kyrgyzstan                       | **Kyrgyz Republic**                     | Kyrgyzstan                                               |
# | Laos                             | **Lao PDR**                             | **Lao People's Democratic Republic**                     |
# | Macedonia                        | **North Macedonia**                     | **North Macedonia**                                      |
# | Micronesia                       | **Micronesia, Fed. Sts.**               | Micronesia                                               |
# | Moldova                          | Moldova                                 | **Republic of Moldova**                                  |
# | Niue                             | _N/A_                                   | Niue                                                     |
# | North Korea                      | **Korea, Dem. People's Rep.**           | **Democratic People's Republic of Korea**                |
# | Republic of Congo                | **Congo, Rep.**                         | **Congo**                                                |
# | Russia                           | **Russian Federation**                  | **Russian Federation**                                   |
# | Saint Kitts and Nevis            | **St. Kitts and Nevis**                 | Saint Kitts and Nevis                                    |
# | Saint Lucia                      | **St. Lucia**                           | Saint Lucia                                              |
# | Saint Vincent and the Grenadines | **St. Vincent and the Grenadines**      | Saint Vincent and the Grenadines                         |
# | Slovakia                         | **Slovak Republic**                     | Slovakia                                                 |
# | South Korea                      | **Korea, Rep.**                         | **Republic of Korea**                                    |
# | Syria                            | **Syrian Arab Republic**                | **Syrian Arab Republic**                                 |
# | Tanzania                         | Tanzania                                | **United Republic of Tanzania**                          |
# | Turkey                           | **Turkiye**                             | **Türkiye**                                              |
# | United Kingdom                   | United Kingdom                          | **United Kingdom of Great Britain and Northern Ireland** |
# | United States                    | United States                           | **United States of America**                             |
# | Venezuela                        | **Venezuela, RB**                       | **Venezuela (Bolivarian Republic of)**                   |
# | Vietnam                          | Vietnam                                 | **Viet Nam**                                             |
# | Yemen                            | **Yemen, Rep**                          | Yemen                                                    |

# %%
climate_rename_list = [
    "Bahamas",
    "Bolivia",
    "Brunei",
    "Cape Verde",
    "Cook Islands",
    "Côte d'Ivoire",
    "Czech Republic",
    "Democratic Republic of the Congo",
    "Egypt",
    "European Union (27)",
    "Gambia",
    "Iran",
    "Kyrgyzstan",
    "Laos",
    "Macedonia",
    "Micronesia",
    "Moldova",
    "Niue",
    "North Korea",
    "Republic of Congo",
    "Russia",
    "Saint Kitts and Nevis",
    "Saint Lucia",
    "Saint Vincent and the Grenadines",
    "Slovakia",
    "South Korea",
    "Syria",
    "Tanzania",
    "Turkey",
    "United Kingdom",
    "United States",
    "Venezuela",
    "Vietnam",
    "Yemen",
]

wdi_rename_list = [
    "Bahamas, The",
    "Bolivia",
    "Brunei Darussalam",
    "Cabo Verde",
    "",
    "Cote d'Ivoire",
    "Czech Republic",
    "Congo, Dem. Rep.",
    "Egypt, Arab Rep.",
    "European Union",
    "Gambia, The",
    "Iran, Islamic Rep.",
    "Kyrgyz Republic",
    "Lao PDR",
    "North Macedonia",
    "Micronesia, Fed. Sts.",
    "Moldova",
    "",
    "Korea, Dem. People's Rep.",
    "Congo, Rep.",
    "Russian Federation",
    "St. Kitts and Nevis",
    "St. Lucia",
    "St. Vincent and the Grenadines",
    "Slovak Republic",
    "Korea, Rep.",
    "Syrian Arab Republic",
    "Tanzania",
    "Turkiye",
    "United Kingdom",
    "United States",
    "Venezuela, RB",
    "Vietnam",
    "Yemen, Rep.",
]

un_sds_rename_list = [
    "Bahamas",
    "Bolivia (Plurinational State of)",
    "Brunei Darussalam",
    "Cabo Verde",
    "Cook Islands",
    "Côte d'Ivoire",
    "Czechia",
    "Democratic Republic of the Congo",
    "Egypt",
    "",
    "Gambia",
    "Iran (Islamic Republic of)",
    "Kyrgyzstan",
    "Lao People's Democratic Republic",
    "North Macedonia",
    "Micronesia",
    "Republic of Moldova",
    "Niue",
    "Democratic People's Republic of Korea",
    "Congo",
    "Russian Federation",
    "Saint Kitts and Nevis",
    "Saint Lucia",
    "Saint Vincent and the Grenadines",
    "Slovakia",
    "Republic of Korea",
    "Syrian Arab Republic",
    "United Republic of Tanzania",
    "Türkiye",
    "United Kingdom of Great Britain and Northern Ireland",
    "United States of America",
    "Venezuela (Bolivarian Republic of)",
    "Viet Nam",
    "Yemen",
]

# %% [markdown]
# # Generating the Clean Output
#
# Generating the list of years that we are focusing on for our analysis, 1990-2019.

# %%
years = list(map(str, range(1990, 2020)))

# %%
wdi_df_clean = wdi_df[
    [
        "Country Name",
        "Country Code",
        "Indicator Name",
        "Indicator Code",
        *years,
    ]
]

wdi_rename_dict = dict(zip(wdi_rename_list, climate_rename_list))
wdi_df_clean = wdi_df_clean.replace(wdi_rename_dict).dropna(subset=years, how="all")
wdi_df_clean = wdi_df_clean[wdi_df_clean["Country Name"].isin(climate_countries)]

# Uncomment to overwrite clean output
# wdi_df_clean.to_csv("./data/wdi_clean.csv", index=False)

# Output the first 100 records as a sample set
wdi_df_clean.head(100).to_csv("./data/wdi_clean_sample.csv", index=False)

wdi_df_clean.head()
# Out:
#               Country Name Country Code  \
# 18746  European Union (27)          EUU
# 18747  European Union (27)          EUU
# 18748  European Union (27)          EUU
# 18749  European Union (27)          EUU
# 18750  European Union (27)          EUU
#
#                                           Indicator Name     Indicator Code  \
# 18746  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 18747  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 18748  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 18749            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 18750  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#         1990   1991   1992   1993   1994   1995  ...        2010        2011  \
# 18746    NaN    NaN    NaN    NaN    NaN    NaN  ...   98.995793   99.060575
# 18747    NaN    NaN    NaN    NaN    NaN    NaN  ...   97.497321   97.638137
# 18748    NaN    NaN    NaN    NaN    NaN    NaN  ...   99.869291   99.869739
# 18749  100.0  100.0  100.0  100.0  100.0  100.0  ...  100.000000  100.000000
# 18750  100.0  100.0  100.0  100.0  100.0  100.0  ...  100.000000  100.000000
#
#              2012        2013        2014        2015        2016        2017  \
# 18746   99.098573   99.134294   99.169027   99.197882   99.221345   99.424531
# 18747   97.732486   97.857445   97.967160   98.018315   98.103910   98.208828
# 18748   99.874219   99.878765   99.879905   99.881077   99.882307   99.883422
# 18749  100.000000  100.000000  100.000000  100.000000   99.960196  100.000000
# 18750  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#              2018        2019
# 18746   99.428916   99.458748
# 18747   98.274355   98.321068
# 18748   99.881291   99.888532
# 18749  100.000000  100.000000
# 18750  100.000000  100.000000
#
# [5 rows x 34 columns]

# %% [markdown]
# The UN SDS Poverty data required some extra manipulation here. We dropped irrelevant columns and pivoted the data from a long to wide format to match the other two datasets.

# %%
# fmt:off
un_sds_clean = un_sds_df[
    un_sds_df["TimePeriod"].ge(1990) & un_sds_df["TimePeriod"].le(2019) & ~un_sds_df["Quantile"].eq("Q1")
].drop(["Goal", "Target", "Indicator", "GeoAreaCode", "Time_Detail", "TimeCoverage", "UpperBound", "LowerBound", "BasePeriod", "Source", "GeoInfoUrl", "FootNote", "Hazard type", "Quantile", "Nature", "Observation Status", "Reporting Type"], axis="columns" )
# fmt:on

un_sds_rename_dict = dict(zip(un_sds_rename_list, climate_rename_list))
un_sds_clean = un_sds_clean.replace(un_sds_rename_dict)
un_sds_clean = un_sds_clean[un_sds_clean["GeoAreaName"].isin(climate_countries)]

# %%
un_sds_clean_pivot = un_sds_clean.pivot(
    index=[
        "SeriesCode",
        "SeriesDescription",
        "GeoAreaName",
        "Age",
        "Location",
        "Sex",
        "Units",
    ],
    columns="TimePeriod",
    values="Value",
)

# Uncomment to overwrite clean output
# un_sds_clean_pivot.to_csv("./data/un_sds_clean.csv")

un_sds_clean_pivot.head()
# Out:
# TimePeriod                                                                                             1990  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1991  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1992  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1993  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1994  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1995  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1996  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1997  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1998  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             1999  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT   NaN
#                                                                  Austria     NaN NaN      NaN PERCENT   NaN
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT   NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT   NaN
#                                                                  Canada      NaN NaN      NaN PERCENT   NaN
#
# TimePeriod                                                                                             ...  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units    ...
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  ...
#                                                                  Austria     NaN NaN      NaN PERCENT  ...
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT  ...
#                                                                  Belgium     NaN NaN      NaN PERCENT  ...
#                                                                  Canada      NaN NaN      NaN PERCENT  ...
#
# TimePeriod                                                                                               2010  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0329
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0071
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0345
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0364
#
# TimePeriod                                                                                               2011  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0376
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0066
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0315
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0410
#
# TimePeriod                                                                                               2012  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0383
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0073
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0274
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0409
#
# TimePeriod                                                                                               2013  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0321
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0062
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0234
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0422
#
# TimePeriod                                                                                               2014  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0307
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0086
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT  0.0013
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0265
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0317
#
# TimePeriod                                                                                               2015  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0325
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0057
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0215
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0301
#
# TimePeriod                                                                                               2016  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0230
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0053
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT  0.0004
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0233
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0303
#
# TimePeriod                                                                                               2017  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0235
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0045
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT     NaN
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0199
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0277
#
# TimePeriod                                                                                               2018  \
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0296
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0056
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT  0.0002
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0187
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0261
#
# TimePeriod                                                                                               2019
# SeriesCode    SeriesDescription                                  GeoAreaName Age Location Sex Units
# DC_ODA_POVDLG Official development assistance grants for pove... Australia   NaN NaN      NaN PERCENT  0.0220
#                                                                  Austria     NaN NaN      NaN PERCENT  0.0046
#                                                                  Azerbaijan  NaN NaN      NaN PERCENT  0.0047
#                                                                  Belgium     NaN NaN      NaN PERCENT  0.0191
#                                                                  Canada      NaN NaN      NaN PERCENT  0.0217
#
# [5 rows x 30 columns]

# %%
# %reload_ext watermark

# %watermark -iv -v -m
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.5.0
#
# Compiler    : Clang 13.1.6 (clang-1316.0.21.2.5)
# OS          : Darwin
# Release     : 21.5.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 8
# Architecture: 64bit
#
# sys   : 3.10.6 (main, Aug 30 2022, 05:12:36) [Clang 13.1.6 (clang-1316.0.21.2.5)]
# pandas: 1.5.0
